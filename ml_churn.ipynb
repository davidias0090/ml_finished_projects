# %% [markdown]
# #Bibliotecas e Leitura dos Dados

# %%
import pandas as pd
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# Construção do modelo machine learning
# Treino 75% dados - fit
# Teste 25% - predict -> Acuracia(verificao se a bom ou ruim o modelo que foi treinado)
# Se ACURACIA boa JOGA O MODELO NO MUNDO!!!
url = 'https://raw.githubusercontent.com/davidias0090/ml_finished_projects/main/Customer-Churn.csv' # Use raw file URL for direct download
df = pd.read_csv(url)
df.head(10)
# Out:
#    Maior65Anos Conjuge Dependentes  MesesDeContrato TelefoneFixo  \
# 0            0     Sim         Nao                1          Nao
# 1            0     Nao         Nao               34          Sim
# 2            0     Nao         Nao                2          Sim
# 3            0     Nao         Nao               45          Nao
# 4            0     Nao         Nao                2          Sim
# 5            0     Nao         Nao                8          Sim
# 6            0     Nao         Sim               22          Sim
# 7            0     Nao         Nao               10          Nao
# 8            0     Sim         Nao               28          Sim
# 9            0     Nao         Sim               62          Sim
#
#   VariasLinhasTelefonicas ServicoDeInternet SegurancaOnline BackupOnline  \
# 0    SemServicoTelefonico               DSL             Nao          Sim
# 1                     Nao               DSL             Sim          Nao
# 2                     Nao               DSL             Sim          Sim
# 3    SemServicoTelefonico               DSL             Sim          Nao
# 4                     Nao       FibraOptica             Nao          Nao
# 5                     Sim       FibraOptica             Nao          Nao
# 6                     Sim       FibraOptica             Nao          Sim
# 7    SemServicoTelefonico               DSL             Sim          Nao
# 8                     Sim       FibraOptica             Nao          Nao
# 9                     Nao               DSL             Sim          Sim
#
#   SeguroNoDispositivo SuporteTecnico TVaCabo StreamingDeFilmes TipoDeContrato  \
# 0                 Nao            Nao     Nao               Nao    Mensalmente
# 1                 Sim            Nao     Nao               Nao          UmAno
# 2                 Nao            Nao     Nao               Nao    Mensalmente
# 3                 Sim            Sim     Nao               Nao          UmAno
# 4                 Nao            Nao     Nao               Nao    Mensalmente
# 5                 Sim            Nao     Sim               Sim    Mensalmente
# 6                 Nao            Nao     Sim               Nao    Mensalmente
# 7                 Nao            Nao     Nao               Nao    Mensalmente
# 8                 Sim            Sim     Sim               Sim    Mensalmente
# 9                 Nao            Nao     Nao               Nao          UmAno
#
#   PagamentoOnline FormaDePagamento  ContaMensal Churn
# 0             Sim    ChequeDigital        29.85   Nao
# 1             Nao      ChequePapel        56.95   Nao
# 2             Sim      ChequePapel        53.85   Sim
# 3             Nao    DebitoEmConta        42.30   Nao
# 4             Sim    ChequeDigital        70.70   Sim
# 5             Sim    ChequeDigital        99.65   Sim
# 6             Sim  CartaoDeCredito        89.10   Nao
# 7             Nao      ChequePapel        29.75   Nao
# 8             Sim    ChequeDigital       104.80   Sim
# 9             Nao    DebitoEmConta        56.15   Nao

# %% [markdown]
# ## Renomeando Colunas e separando features

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

troca = {
    'Sim': 1,
    'Nao': 0
}

df['Churn'] = df['Churn'].map(troca)
x = df[['Maior65Anos','Conjuge','Dependentes','MesesDeContrato','TelefoneFixo','PagamentoOnline','SegurancaOnline','BackupOnline','TVaCabo','StreamingDeFilmes']]
y = df['Churn']
df.head()
# Out:
#    Maior65Anos Conjuge Dependentes  MesesDeContrato TelefoneFixo  \
# 0            0     Sim         Nao                1          Nao
# 1            0     Nao         Nao               34          Sim
# 2            0     Nao         Nao                2          Sim
# 3            0     Nao         Nao               45          Nao
# 4            0     Nao         Nao                2          Sim
#
#   VariasLinhasTelefonicas ServicoDeInternet SegurancaOnline BackupOnline  \
# 0    SemServicoTelefonico               DSL             Nao          Sim
# 1                     Nao               DSL             Sim          Nao
# 2                     Nao               DSL             Sim          Sim
# 3    SemServicoTelefonico               DSL             Sim          Nao
# 4                     Nao       FibraOptica             Nao          Nao
#
#   SeguroNoDispositivo SuporteTecnico TVaCabo StreamingDeFilmes TipoDeContrato  \
# 0                 Nao            Nao     Nao               Nao    Mensalmente
# 1                 Sim            Nao     Nao               Nao          UmAno
# 2                 Nao            Nao     Nao               Nao    Mensalmente
# 3                 Sim            Sim     Nao               Nao          UmAno
# 4                 Nao            Nao     Nao               Nao    Mensalmente
#
#   PagamentoOnline FormaDePagamento  ContaMensal  Churn
# 0             Sim    ChequeDigital        29.85      0
# 1             Nao      ChequePapel        56.95      0
# 2             Sim      ChequePapel        53.85      1
# 3             Nao    DebitoEmConta        42.30      0
# 4             Sim    ChequeDigital        70.70      1

# %% [markdown]
# #Separação do Treino e Teste

# %%
# Separar treino e teste
seed = 20
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.25, random_state=seed,stratify=y)

print('Treinamento com %d elementos e testarmos com %d elementos' % (len(train_x), len(test_x)))
# Out:
# Treinamento com 5282 elementos e testarmos com 1761 elementos

# %% [markdown]
# ## Modelo Classificador

# %%
# Check for other columns with string values and convert them to numerical representations
for column in x.columns:
    if x[column].dtype == 'object':  # Check if the column has object (string) dtype
        unique_values = x[column].unique()
        mapping = {value: i for i, value in enumerate(unique_values)}
        x[column] = x[column].map(mapping)  # Convert string values to numerical using a mapping

# %%
model = LinearSVC() # Cria o modelo
model.fit(train_x, train_y) # treino

result = model.predict(test_x) # teste

acuracia = accuracy_score(test_y, result) # compara vetores
acuracia_model = model.score(test_x, test_y) # roda teste

print("Acuracia_model: ", (acuracia_model*100), "%")
# Out:
# Acuracia_model:  77.8534923339012 %
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %% [markdown]
# ## COMPARAÇÃO ACURACIA DUMMY (BASELINE)

# %%
from sklearn.dummy import DummyClassifier

dummy_stratified = DummyClassifier()
dummy_stratified.fit(train_x, train_y)
acuracia_dummy = dummy_stratified.score(test_x, test_y)

print("Acuracia Dummy: ", (acuracia_dummy*100), "%")
# Out:
# Acuracia Dummy:  73.480976717774 %

# %%
test_y.value_counts()
# Out:
# Churn
# 0    1294
# 1     467
# Name: count, dtype: int64
